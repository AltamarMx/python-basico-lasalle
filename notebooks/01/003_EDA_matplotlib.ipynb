# %%
import pandas as pd
import matplotlib.pyplot as plt
from dateutil.parser import parse

# %%
f = "../../data/Irradiancia.csv"
pd.read_csv(f,index_col=0,parse_dates=True)
# Out:
#                      I_glo_Avg  I_dir_Avg  I_dif_Avg  I_glo_inc_Avg  I_uv_Avg  \
# TIMESTAMP
# 2023-05-31 18:59:00       9.66     21.710      7.391          6.752     0.000
# 2023-05-31 19:00:00       9.26      0.000      7.020          6.398     0.000
# 2023-05-31 19:01:00       8.83      2.945      6.603          5.985     0.000
# 2023-05-31 19:02:00       8.46      3.643      6.262          5.590     0.000
# 2023-05-31 19:03:00       8.02      7.574      5.952          5.082     0.000
# ...                        ...        ...        ...            ...       ...
# 2025-04-30 18:01:00      41.86      0.435     35.590         46.760     0.003
# 2025-04-30 18:02:00      40.71      0.608     35.360         46.280     0.003
# 2025-04-30 18:03:00      40.79      0.496     35.180         46.710     0.003
# 2025-04-30 18:04:00      41.54      0.560     35.620         47.210     0.003
# 2025-04-30 18:05:00      41.83      0.538     35.740         47.700     0.003
#
# ...

# %%
f = "../../data/Irradiancia.parquet"
I = pd.read_parquet(f)
#Arreglo los datos
I.sort_index(inplace=True)
I = I[I.index.year>2022]

# %%
I.plot(subplots=True, figsize=(12,8))
# Out:
# array([<Axes: xlabel='TIMESTAMP'>, <Axes: xlabel='TIMESTAMP'>,
#        <Axes: xlabel='TIMESTAMP'>, <Axes: xlabel='TIMESTAMP'>,
#        <Axes: xlabel='TIMESTAMP'>, <Axes: xlabel='TIMESTAMP'>],
#       dtype=object)

# %%
fig, ax = plt.subplots(figsize=(12,4))

f1 = parse("2024-03-10")
f2 = f1 + pd.Timedelta("1D")

ax.plot(I.I_glo_Avg,label="I_glo")
ax.plot(I.I_dir_Avg,label="I_dir")
ax.plot(I.I_dif_Avg,label="I_dif")

ax.set_xlim(f1,f2)
ax.set_ylim(0,1200)
ax.legend()
